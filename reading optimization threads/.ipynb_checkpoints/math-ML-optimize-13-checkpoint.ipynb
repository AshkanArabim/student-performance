# %%
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
# model to predit math scores

df = pd.read_csv("./StudentsPerformance.csv")

#drop non-math scores
df = df.drop('reading score', axis = 1)
df = df.drop('writing score', axis = 1)

# convert categories into machine readable format
df = pd.get_dummies(df)

# select values you wanna predict
labels = np.array(df["math score"])

# drop labels
df = df.drop('math score', axis = 1)

# save feature names for later use
df_list = list(df.columns)

# convert df to numpy array
df = np.array(df)

# %%
# split data into training and testing sets

#the fuck is random state exactly???
# random state 20 is dope

r1 = 0
r2 = 0
accuracy = 0
for x in range(0, 13):
    for y in range(0, 10):
        train_df, test_df, train_labels, test_labels = train_test_split(df, labels, test_size = 0.25, random_state = x)

        print('--------', 'first:', x, 'second: ', y)

        # define model with 1000 trees
        # random state 99 is dope: 89.03
        rf = RandomForestRegressor(n_estimators = 1000, random_state = y)

        # Train on training data
        rf.fit(train_df, train_labels)

        # predict...
        predictions = rf.predict(test_df)

        # calculate absolute errors (+/- doesn't matter)
        errors = abs(predictions - test_labels)
        avg_error = np.mean(errors)
        print('average absolute error:', avg_error, "points")
        temp_accuracy = 100 - avg_error
        
        print(temp_accuracy)
        if (temp_accuracy > accuracy):
            r1 = x
            r2 = y
            print('replacing')
            accuracy = temp_accuracy

print('accuracy:', accuracy)
# Out:
# -------- first: 0 second:  0
# average absolute error: 12.065161596086721 points
# 87.93483840391328
# replacing
# -------- first: 0 second:  1
# average absolute error: 12.056006258206176 points
# 87.94399374179382
# replacing
# -------- first: 0 second:  2
# average absolute error: 12.059564161220377 points
# 87.94043583877962
# -------- first: 0 second:  3
# average absolute error: 12.086563508498497 points
# 87.9134364915015
# -------- first: 0 second:  4
# average absolute error: 12.091719205786452 points
# 87.90828079421355
# -------- first: 0 second:  5
# average absolute error: 12.022335568701372 points
# 87.97766443129862
# replacing
# -------- first: 0 second:  6
# average absolute error: 12.103893660861642 points
# 87.89610633913836
# -------- first: 0 second:  7
# average absolute error: 12.068648754298229 points
# 87.93135124570178
# -------- first: 0 second:  8
# average absolute error: 12.085312918858111 points
# 87.91468708114189
# -------- first: 0 second:  9
# average absolute error: 12.056111764480343 points
# 87.94388823551965
# -------- first: 0 second:  10
# average absolute error: 12.062363148809057 points
# 87.93763685119094
# -------- first: 0 second:  11
# average absolute error: 12.06658549125926 points
# 87.93341450874074
# -------- first: 0 second:  12
# average absolute error: 12.079970914962333 points
# 87.92002908503767
# -------- first: 0 second:  13
# average absolute error: 12.064299584157528 points
# 87.93570041584248
# -------- first: 0 second:  14
# average absolute error: 12.089247344838103 points
# 87.9107526551619
# -------- first: 0 second:  15
# average absolute error: 12.070185596351923 points
# 87.92981440364808
# -------- first: 0 second:  16
# average absolute error: 12.053860948640875 points
# 87.94613905135913
# -------- first: 0 second:  17
# average absolute error: 12.079952026442589 points
# 87.92004797355742
# -------- first: 0 second:  18
# average absolute error: 12.08154994861233 points
# 87.91845005138767
# -------- first: 0 second:  19
# average absolute error: 12.07219320349165 points
# 87.92780679650835
# -------- first: 0 second:  20
# average absolute error: 12.083736110094499 points
# 87.91626388990551
# -------- first: 0 second:  21
# average absolute error: 12.068373913634808 points
# 87.93162608636518
# -------- first: 0 second:  22
# average absolute error: 12.047642802596645 points
# 87.95235719740336
# -------- first: 0 second:  23
# average absolute error: 12.082820331731194 points
# 87.9171796682688
# -------- first: 0 second:  24
# average absolute error: 12.09238875760344 points
# 87.90761124239656
# -------- first: 1 second:  0
# average absolute error: 11.148113918835861 points
# 88.85188608116414
# replacing
# -------- first: 1 second:  1
# average absolute error: 11.169520873398083 points
# 88.83047912660192
# -------- first: 1 second:  2
# average absolute error: 11.156624775156267 points
# 88.84337522484373
# -------- first: 1 second:  3
# average absolute error: 11.137189566719979 points
# 88.86281043328002
# replacing
# -------- first: 1 second:  4
# average absolute error: 11.129621678672077 points
# 88.87037832132792
# replacing
# -------- first: 1 second:  5
# average absolute error: 11.14373270704953 points
# 88.85626729295046
# -------- first: 1 second:  6
# average absolute error: 11.172097934082313 points
# 88.82790206591768
# -------- first: 1 second:  7
# average absolute error: 11.178633961596569 points
# 88.82136603840343
# -------- first: 1 second:  8
# average absolute error: 11.208559220218913 points
# 88.79144077978108
# -------- first: 1 second:  9
# average absolute error: 11.159235453647227 points
# 88.84076454635277
# -------- first: 1 second:  10
# average absolute error: 11.155943856279857 points
# 88.84405614372014
# -------- first: 1 second:  11
# average absolute error: 11.172291584824462 points
# 88.82770841517554
# -------- first: 1 second:  12
# average absolute error: 11.133356143642843 points
# 88.86664385635716
# -------- first: 1 second:  13
# average absolute error: 11.145690824020758 points
# 88.85430917597924
# -------- first: 1 second:  14
# average absolute error: 11.163853091199242 points
# 88.83614690880076
# -------- first: 1 second:  15
# average absolute error: 11.176629816029587 points
# 88.82337018397041
# -------- first: 1 second:  16
# average absolute error: 11.138095700079795 points
# 88.86190429992021
# -------- first: 1 second:  17
# average absolute error: 11.209938643829854 points
# 88.79006135617014
# -------- first: 1 second:  18
# average absolute error: 11.171205460703186 points
# 88.82879453929681
# -------- first: 1 second:  19
# average absolute error: 11.170211862296595 points
# 88.8297881377034
# -------- first: 1 second:  20
# average absolute error: 11.140987455028196 points
# 88.8590125449718
# -------- first: 1 second:  21
# average absolute error: 11.132148389314725 points
# 88.86785161068528
# -------- first: 1 second:  22
# average absolute error: 11.172865136893124 points
# 88.82713486310688
# -------- first: 1 second:  23
# average absolute error: 11.160699296840072 points
# 88.83930070315992
# -------- first: 1 second:  24
# average absolute error: 11.177082134191076 points
# 88.82291786580892
# -------- first: 2 second:  0
# average absolute error: 12.280832431664399 points
# 87.7191675683356
# -------- first: 2 second:  1
# average absolute error: 12.24343324901232 points
# 87.75656675098767
# -------- first: 2 second:  2
# average absolute error: 12.27704829750267 points
# 87.72295170249733
# -------- first: 2 second:  3
# average absolute error: 12.236581455451264 points
# 87.76341854454874
# -------- first: 2 second:  4
# average absolute error: 12.26313904972111 points
# 87.7368609502789
# -------- first: 2 second:  5
# average absolute error: 12.266509673761814 points
# 87.73349032623818
# -------- first: 2 second:  6
# average absolute error: 12.262614133661963 points
# 87.73738586633803
# -------- first: 2 second:  7
# average absolute error: 12.2476790455029 points
# 87.7523209544971
# -------- first: 2 second:  8
# average absolute error: 12.299257479960291 points
# 87.70074252003971
# -------- first: 2 second:  9
# average absolute error: 12.274011004391642 points
# 87.72598899560836
# -------- first: 2 second:  10
# average absolute error: 12.287307414301534 points
# 87.71269258569846
# -------- first: 2 second:  11
# average absolute error: 12.262138488229743 points
# 87.73786151177026
# -------- first: 2 second:  12
# average absolute error: 12.27406553715355 points
# 87.72593446284645
# -------- first: 2 second:  13
# average absolute error: 12.271682726958733 points
# 87.72831727304127
# -------- first: 2 second:  14
# average absolute error: 12.296600737567934 points
# 87.70339926243207
# -------- first: 2 second:  15
# average absolute error: 12.269919194788693 points
# 87.7300808052113
# -------- first: 2 second:  16
# average absolute error: 12.248629682254148 points
# 87.75137031774585
# -------- first: 2 second:  17
# average absolute error: 12.274395636753578 points
# 87.72560436324642
# -------- first: 2 second:  18
# average absolute error: 12.275518627658643 points
# 87.72448137234136
# -------- first: 2 second:  19
# average absolute error: 12.268604599794784 points
# 87.73139540020522
# -------- first: 2 second:  20
# average absolute error: 12.256979982676105 points
# 87.7430200173239
# -------- first: 2 second:  21
# average absolute error: 12.245516683350436 points
# 87.75448331664957
# -------- first: 2 second:  22
# average absolute error: 12.26728723860493 points
# 87.73271276139508
# -------- first: 2 second:  23
# average absolute error: 12.26992733564564 points
# 87.73007266435437
# -------- first: 2 second:  24
# average absolute error: 12.267290760631246 points
# 87.73270923936876
# -------- first: 3 second:  0
# average absolute error: 12.292227989660873 points
# 87.70777201033913
# -------- first: 3 second:  1
# average absolute error: 12.317318666370673 points
# 87.68268133362933
# -------- first: 3 second:  2
# average absolute error: 12.31176637335057 points
# 87.68823362664943
# -------- first: 3 second:  3
# average absolute error: 12.3121752354506 points
# 87.6878247645494
# -------- first: 3 second:  4
# average absolute error: 12.305457454157754 points
# 87.69454254584224
# -------- first: 3 second:  5
# average absolute error: 12.321909922238834 points
# 87.67809007776117
# -------- first: 3 second:  6
# average absolute error: 12.327400381239546 points
# 87.67259961876046
# -------- first: 3 second:  7
# average absolute error: 12.3201814936806 points
# 87.6798185063194
# -------- first: 3 second:  8
# average absolute error: 12.30223322014093 points
# 87.69776677985907
# -------- first: 3 second:  9
# average absolute error: 12.307556663862842 points
# 87.69244333613716
# -------- first: 3 second:  10
# average absolute error: 12.314697474734162 points
# 87.68530252526584
# -------- first: 3 second:  11
# average absolute error: 12.293359313560137 points
# 87.70664068643987
# -------- first: 3 second:  12
# average absolute error: 12.333135570814004 points
# 87.66686442918599
# -------- first: 3 second:  13
# average absolute error: 12.313910719383072 points
# 87.68608928061693
# -------- first: 3 second:  14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26216\3931512700.py in <module>
#      18
#      19         # Train on training data
# ---> 20         rf.fit(train_df, train_labels)
#      21
#      22         # predict...
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     448             # parallel_backend contexts set at a higher level,
#     449             # since correctness does not rely on using threads.
# --> 450             trees = Parallel(
#     451                 n_jobs=self.n_jobs,
#     452                 verbose=self.verbose,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
#    1044                 self._iterating = self._original_iterator is not None
#    1045
# -> 1046             while self.dispatch_one_batch(iterator):
#    1047                 pass
#    1048
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     859                 return False
#     860             else:
# --> 861                 self._dispatch(tasks)
#     862                 return True
#     863
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in _dispatch(self, batch)
#     777         with self._lock:
#     778             job_idx = len(self._jobs)
# --> 779             job = self._backend.apply_async(batch, callback=cb)
#     780             # A job can complete so quickly than its callback is
#     781             # called before we get here, causing self._jobs to
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~\anaconda3\lib\site-packages\joblib\_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~\anaconda3\lib\site-packages\sklearn\utils\fixes.py in __call__(self, *args, **kwargs)
#     214     def __call__(self, *args, **kwargs):
#     215         with config_context(**self.config):
# --> 216             return self.function(*args, **kwargs)
#     217
#     218
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in _parallel_build_trees(tree, forest, X, y, sample_weight, tree_idx, n_trees, verbose, class_weight, n_samples_bootstrap)
#     183             curr_sample_weight *= compute_sample_weight("balanced", y, indices=indices)
#     184
# --> 185         tree.fit(X, y, sample_weight=curr_sample_weight, check_input=False)
#     186     else:
#     187         tree.fit(X, y, sample_weight=sample_weight, check_input=False)
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1313         """
#    1314
# -> 1315         super().fit(
#    1316             X,
#    1317             y,
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:
