# %%
import pandas as pd
import numpy as np
import sklearn as sk
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
# model to predit math scores

df = pd.read_csv("./StudentsPerformance.csv")

#drop non-math scores
df = df.drop('reading score', axis = 1)
df = df.drop('writing score', axis = 1)

# convert categories into machine readable format
df = pd.get_dummies(df)

# select values you wanna predict
labels = np.array(df["math score"])

# drop labels
df = df.drop('math score', axis = 1)

# save feature names for later use
df_list = list(df.columns)

# convert df to numpy array
df = np.array(df)

# %%
# split data into training and testing sets

#the fuck is random state exactly???
# random state 20 is dope

r1 = 0
r2 = 0
accuracy = 0
for x in range(0, 13):
    for y in range(0, 10):
        train_df, test_df, train_labels, test_labels = train_test_split(df, labels, test_size = 0.25, random_state = x)

        print('--------', 'first:', x, 'second: ', y)

        # define model with 1000 trees
        # random state 99 is dope: 89.03
        rf = RandomForestRegressor(n_estimators = 1000, random_state = y)

        # Train on training data
        rf.fit(train_df, train_labels)

        # predict...
        predictions = rf.predict(test_df)

        # calculate absolute errors (+/- doesn't matter)
        errors = abs(predictions - test_labels)
        avg_error = np.mean(errors)
        print('average absolute error:', avg_error, "points")
        temp_accuracy = 100 - avg_error
        
        print(temp_accuracy)
        if (temp_accuracy > accuracy):
            r1 = x
            r2 = y
            print('replacing')
            accuracy = temp_accuracy

print('accuracy:', accuracy)
# Out:
# -------- first: 0 second:  0
# average absolute error: 12.065161596086721 points
# 87.93483840391328
# replacing
# -------- first: 0 second:  1
# average absolute error: 12.056006258206176 points
# 87.94399374179382
# replacing
# -------- first: 0 second:  2
# average absolute error: 12.059564161220377 points
# 87.94043583877962
# -------- first: 0 second:  3
# average absolute error: 12.086563508498497 points
# 87.9134364915015
# -------- first: 0 second:  4
# average absolute error: 12.091719205786452 points
# 87.90828079421355
# -------- first: 0 second:  5
# average absolute error: 12.022335568701372 points
# 87.97766443129862
# replacing
# -------- first: 0 second:  6
# average absolute error: 12.103893660861642 points
# 87.89610633913836
# -------- first: 0 second:  7
# average absolute error: 12.068648754298229 points
# 87.93135124570178
# -------- first: 0 second:  8
# average absolute error: 12.085312918858111 points
# 87.91468708114189
# -------- first: 0 second:  9
# average absolute error: 12.056111764480343 points
# 87.94388823551965
# -------- first: 1 second:  0
# average absolute error: 11.148113918835861 points
# 88.85188608116414
# replacing
# -------- first: 1 second:  1
# average absolute error: 11.169520873398083 points
# 88.83047912660192
# -------- first: 1 second:  2
# average absolute error: 11.156624775156267 points
# 88.84337522484373
# -------- first: 1 second:  3
# average absolute error: 11.137189566719979 points
# 88.86281043328002
# replacing
# -------- first: 1 second:  4
# average absolute error: 11.129621678672077 points
# 88.87037832132792
# replacing
# -------- first: 1 second:  5
# average absolute error: 11.14373270704953 points
# 88.85626729295046
# -------- first: 1 second:  6
# average absolute error: 11.172097934082313 points
# 88.82790206591768
# -------- first: 1 second:  7
# average absolute error: 11.178633961596569 points
# 88.82136603840343
# -------- first: 1 second:  8
# average absolute error: 11.208559220218913 points
# 88.79144077978108
# -------- first: 1 second:  9
# average absolute error: 11.159235453647227 points
# 88.84076454635277
# -------- first: 2 second:  0
# average absolute error: 12.280832431664399 points
# 87.7191675683356
# -------- first: 2 second:  1
# average absolute error: 12.24343324901232 points
# 87.75656675098767
# -------- first: 2 second:  2
# average absolute error: 12.27704829750267 points
# 87.72295170249733
# -------- first: 2 second:  3
# average absolute error: 12.236581455451264 points
# 87.76341854454874
# -------- first: 2 second:  4
# average absolute error: 12.26313904972111 points
# 87.7368609502789
# -------- first: 2 second:  5
# average absolute error: 12.266509673761814 points
# 87.73349032623818
# -------- first: 2 second:  6
# average absolute error: 12.262614133661963 points
# 87.73738586633803
# -------- first: 2 second:  7
# average absolute error: 12.2476790455029 points
# 87.7523209544971
# -------- first: 2 second:  8
# average absolute error: 12.299257479960291 points
# 87.70074252003971
# -------- first: 2 second:  9
# average absolute error: 12.274011004391642 points
# 87.72598899560836
# -------- first: 3 second:  0
# average absolute error: 12.292227989660873 points
# 87.70777201033913
# -------- first: 3 second:  1
# average absolute error: 12.317318666370673 points
# 87.68268133362933
# -------- first: 3 second:  2
# average absolute error: 12.31176637335057 points
# 87.68823362664943
# -------- first: 3 second:  3
# average absolute error: 12.3121752354506 points
# 87.6878247645494
# -------- first: 3 second:  4
# average absolute error: 12.305457454157754 points
# 87.69454254584224
# -------- first: 3 second:  5
# average absolute error: 12.321909922238834 points
# 87.67809007776117
# -------- first: 3 second:  6
# average absolute error: 12.327400381239546 points
# 87.67259961876046
# -------- first: 3 second:  7
# average absolute error: 12.3201814936806 points
# 87.6798185063194
# -------- first: 3 second:  8
# average absolute error: 12.30223322014093 points
# 87.69776677985907
# -------- first: 3 second:  9
# average absolute error: 12.307556663862842 points
# 87.69244333613716
# -------- first: 4 second:  0
# average absolute error: 11.97965066041773 points
# 88.02034933958227
# -------- first: 4 second:  1
# average absolute error: 11.95398629282146 points
# 88.04601370717855
# -------- first: 4 second:  2
# average absolute error: 11.949356326424521 points
# 88.05064367357548
# -------- first: 4 second:  3
# average absolute error: 11.96056861852836 points
# 88.03943138147164
# -------- first: 4 second:  4
# average absolute error: 11.948085918756249 points
# 88.05191408124375
# -------- first: 4 second:  5
# average absolute error: 11.939414779828935 points
# 88.06058522017106
# -------- first: 4 second:  6
# average absolute error: 11.960538604251221 points
# 88.03946139574877
# -------- first: 4 second:  7
# average absolute error: 11.968419546840153 points
# 88.03158045315985
# -------- first: 4 second:  8
# average absolute error: 11.977478513164344 points
# 88.02252148683566
# -------- first: 4 second:  9
# average absolute error: 11.94725733910128 points
# 88.05274266089872
# -------- first: 5 second:  0
# average absolute error: 12.313807751318127 points
# 87.68619224868188
# -------- first: 5 second:  1
# average absolute error: 12.31097177384516 points
# 87.68902822615485
# -------- first: 5 second:  2
# average absolute error: 12.30675202234845 points
# 87.69324797765155
# -------- first: 5 second:  3
# average absolute error: 12.296741452871672 points
# 87.70325854712833
# -------- first: 5 second:  4
# average absolute error: 12.318173415623049 points
# 87.68182658437695
# -------- first: 5 second:  5
# average absolute error: 12.307677432401059 points
# 87.69232256759894
# -------- first: 5 second:  6
# average absolute error: 12.282200893187337 points
# 87.71779910681266
# -------- first: 5 second:  7
# average absolute error: 12.282529033971791 points
# 87.7174709660282
# -------- first: 5 second:  8
# average absolute error: 12.297433472517442 points
# 87.70256652748256
# -------- first: 5 second:  9
# average absolute error: 12.284622877373643 points
# 87.71537712262636
# -------- first: 6 second:  0
# average absolute error: 12.299778938483161 points
# 87.70022106151684
# -------- first: 6 second:  1
# average absolute error: 12.331038192505625 points
# 87.66896180749437
# -------- first: 6 second:  2
# average absolute error: 12.339930343759832 points
# 87.66006965624017
# -------- first: 6 second:  3
# average absolute error: 12.33158992013102 points
# 87.66841007986898
# -------- first: 6 second:  4
# average absolute error: 12.314150788620141 points
# 87.68584921137986
# -------- first: 6 second:  5
# average absolute error: 12.307696604348951 points
# 87.69230339565105
# -------- first: 6 second:  6
# average absolute error: 12.33073384788443 points
# 87.66926615211557
# -------- first: 6 second:  7
# average absolute error: 12.343366432334744 points
# 87.65663356766525
# -------- first: 6 second:  8
# average absolute error: 12.307777130123075 points
# 87.69222286987693
# -------- first: 6 second:  9
# average absolute error: 12.311477708114234 points
# 87.68852229188576
# -------- first: 7 second:  0
# average absolute error: 11.888179331088883 points
# 88.11182066891112
# -------- first: 7 second:  1
# average absolute error: 11.901301356714116 points
# 88.09869864328589
# -------- first: 7 second:  2
# average absolute error: 11.915348668716796 points
# 88.0846513312832
# -------- first: 7 second:  3
# average absolute error: 11.88348320328408 points
# 88.11651679671593
# -------- first: 7 second:  4
# average absolute error: 11.915152938750946 points
# 88.08484706124905
# -------- first: 7 second:  5
# average absolute error: 11.904334060604189 points
# 88.09566593939581
# -------- first: 7 second:  6
# average absolute error: 11.891589283509337 points
# 88.10841071649067
# -------- first: 7 second:  7
# average absolute error: 11.903227084052354 points
# 88.09677291594764
# -------- first: 7 second:  8
# average absolute error: 11.887888590631478 points
# 88.11211140936852
# -------- first: 7 second:  9
# average absolute error: 11.90799297041396 points
# 88.09200702958604
# -------- first: 8 second:  0
# average absolute error: 11.547997786447098 points
# 88.4520022135529
# -------- first: 8 second:  1
# average absolute error: 11.542089987903806 points
# 88.45791001209619
# -------- first: 8 second:  2
# average absolute error: 11.576078716352765 points
# 88.42392128364723
# -------- first: 8 second:  3
# average absolute error: 11.534034901768322 points
# 88.46596509823168
# -------- first: 8 second:  4
# average absolute error: 11.531220464505681 points
# 88.46877953549432
# -------- first: 8 second:  5
# average absolute error: 11.53484382965961 points
# 88.46515617034039
# -------- first: 8 second:  6
# average absolute error: 11.554176974970298 points
# 88.4458230250297
# -------- first: 8 second:  7
# average absolute error: 11.536141375545746 points
# 88.46385862445425
# -------- first: 8 second:  8
# average absolute error: 11.545854957208826 points
# 88.45414504279117
# -------- first: 8 second:  9
# average absolute error: 11.547951710823112 points
# 88.45204828917689
# -------- first: 9 second:  0
# average absolute error: 11.199051902855699 points
# 88.8009480971443
# -------- first: 9 second:  1
# average absolute error: 11.194722626235688 points
# 88.80527737376431
# -------- first: 9 second:  2
# average absolute error: 11.181403646341964 points
# 88.81859635365804
# -------- first: 9 second:  3
# average absolute error: 11.18875430215352 points
# 88.81124569784649
# -------- first: 9 second:  4
# average absolute error: 11.175964791758489 points
# 88.82403520824151
# -------- first: 9 second:  5
# average absolute error: 11.21497093264213 points
# 88.78502906735787
# -------- first: 9 second:  6
# average absolute error: 11.17285543533045 points
# 88.82714456466955
# -------- first: 9 second:  7
# average absolute error: 11.190722126337485 points
# 88.80927787366251
# -------- first: 9 second:  8
# average absolute error: 11.191309807435296 points
# 88.80869019256471
# -------- first: 9 second:  9
# average absolute error: 11.18409937499469 points
# 88.81590062500531
# -------- first: 10 second:  0
# average absolute error: 11.768563297970166 points
# 88.23143670202984
# -------- first: 10 second:  1
# average absolute error: 11.761079242832395 points
# 88.2389207571676
# -------- first: 10 second:  2
# average absolute error: 11.776772923886627 points
# 88.22322707611337
# -------- first: 10 second:  3
# average absolute error: 11.794150107602675 points
# 88.20584989239732
# -------- first: 10 second:  4
# average absolute error: 11.72591714592497 points
# 88.27408285407503
# -------- first: 10 second:  5
# average absolute error: 11.743651164444003 points
# 88.256348835556
# -------- first: 10 second:  6
# average absolute error: 11.764764055386634 points
# 88.23523594461336
# -------- first: 10 second:  7
# average absolute error: 11.770688859317815 points
# 88.22931114068219
# -------- first: 10 second:  8
# average absolute error: 11.731369737507642 points
# 88.26863026249237
# -------- first: 10 second:  9
# average absolute error: 11.745219304518058 points
# 88.25478069548194
# -------- first: 11 second:  0
# average absolute error: 12.218730007752779 points
# 87.78126999224722
# -------- first: 11 second:  1
# average absolute error: 12.210651569161943 points
# 87.78934843083806
# -------- first: 11 second:  2
# average absolute error: 12.222068667836307 points
# 87.77793133216369
# -------- first: 11 second:  3
# average absolute error: 12.19688061931338 points
# 87.80311938068662
# -------- first: 11 second:  4
# average absolute error: 12.207116395303055 points
# 87.79288360469694
# -------- first: 11 second:  5
# average absolute error: 12.256698979362387 points
# 87.74330102063762
# -------- first: 11 second:  6
# average absolute error: 12.194838616888475 points
# 87.80516138311152
# -------- first: 11 second:  7
# average absolute error: 12.25949647178071 points
# 87.74050352821929
# -------- first: 11 second:  8
# average absolute error: 12.241648759847354 points
# 87.75835124015265
# -------- first: 11 second:  9
# average absolute error: 12.257479697276752 points
# 87.74252030272325
# -------- first: 12 second:  0
# average absolute error: 11.268880300876297 points
# 88.7311196991237
# -------- first: 12 second:  1
# average absolute error: 11.255206286609251 points
# 88.74479371339075
# -------- first: 12 second:  2
# average absolute error: 11.278355055924417 points
# 88.72164494407558
# -------- first: 12 second:  3
# average absolute error: 11.293060471039542 points
# 88.70693952896046
# -------- first: 12 second:  4
# average absolute error: 11.267404023901506 points
# 88.7325959760985
# -------- first: 12 second:  5
# average absolute error: 11.269044989835296 points
# 88.7309550101647
# -------- first: 12 second:  6
# average absolute error: 11.28340466530557 points
# 88.71659533469443
# -------- first: 12 second:  7
# average absolute error: 11.263300428345461 points
# 88.73669957165454
# -------- first: 12 second:  8
# average absolute error: 11.272266745776259 points
# 88.72773325422374
# -------- first: 12 second:  9
# average absolute error: 11.264049090762954 points
# 88.73595090923705
# accuracy: 88.87037832132792
